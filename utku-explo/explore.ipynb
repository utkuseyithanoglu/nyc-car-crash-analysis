# %% [markdown]
# # Explore here

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
main_df = pd.read_csv('/Users/utkuseyithanoglu/Desktop/nyc car crash analysis/nyc car crash analysis/data/raw/Motor_Vehicle_Collisions_-_Crashes.csv.download/Motor_Vehicle_Collisions_-_Crashes.csv')
# Out:
# /var/folders/34/1yg1tqgd1b96v45w9k29prnw0000gn/T/ipykernel_5333/2022382304.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   main_df = pd.read_csv('/Users/utkuseyithanoglu/Desktop/nyc car crash analysis/nyc car crash analysis/data/raw/Motor_Vehicle_Collisions_-_Crashes.csv.download/Motor_Vehicle_Collisions_-_Crashes.csv')

# %%
main_df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN  11230.0  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN      NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                  LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                     NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                     NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2  (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                     NaN       THROGS NECK BRIDGE               NaN
# 4                     NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN  ...                    Unspecified
# ...

# %%
main_df.isna().sum().sum()
# Out:
# np.int64(19203336)

# %%
main_df['CRASH DATE'].isna().sum()
# Out:
# np.int64(0)

# %%
main_df['CRASH TIME'].isna().sum()
# Out:
# np.int64(0)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2246476 entries, 0 to 2246475
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
# ...

# %%
main_df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
main_df['CRASH DATE'].min()
# Out:
# '01/01/2013'

# %%
main_df['CRASH DATE'].max()
# Out:
# '12/31/2025'

# %%
main_df.isna().sum()[main_df.isna().sum() > 0]
# Out:
# BOROUGH                           685837
# ZIP CODE                          686119
# LATITUDE                          240625
# LONGITUDE                         240625
# LOCATION                          240625
# ON STREET NAME                    491877
# CROSS STREET NAME                 859587
# OFF STREET NAME                  1846973
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# CONTRIBUTING FACTOR VEHICLE 1       8087
# CONTRIBUTING FACTOR VEHICLE 2     363716
# CONTRIBUTING FACTOR VEHICLE 3    2083909
# CONTRIBUTING FACTOR VEHICLE 4    2209315
# CONTRIBUTING FACTOR VEHICLE 5    2236297
# VEHICLE TYPE CODE 1                16700
# VEHICLE TYPE CODE 2               455409
# VEHICLE TYPE CODE 3              2090300
# VEHICLE TYPE CODE 4              2210669
# VEHICLE TYPE CODE 5              2236617
# dtype: int64

# %%
copy_df = main_df.copy()

# %%
copy_df =copy_df.dropna(subset=["LATITUDE","LONGITUDE"])

# %%
copy_df.isna().sum()[copy_df.isna().sum() > 0]
# Out:
# BOROUGH                           483056
# ZIP CODE                          483312
# ON STREET NAME                    435210
# CROSS STREET NAME                 762758
# OFF STREET NAME                  1632685
# NUMBER OF PERSONS INJURED             16
# NUMBER OF PERSONS KILLED              28
# CONTRIBUTING FACTOR VEHICLE 1       7449
# CONTRIBUTING FACTOR VEHICLE 2     331699
# CONTRIBUTING FACTOR VEHICLE 3    1861302
# CONTRIBUTING FACTOR VEHICLE 4    1972450
# CONTRIBUTING FACTOR VEHICLE 5    1996566
# VEHICLE TYPE CODE 1                15428
# VEHICLE TYPE CODE 2               418627
# VEHICLE TYPE CODE 3              1867113
# VEHICLE TYPE CODE 4              1973673
# VEHICLE TYPE CODE 5              1996850
# dtype: int64

# %%
copy_df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')
